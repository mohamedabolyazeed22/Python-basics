# %% [markdown]
# # Your First Python Program

# %%
print('hello, world')
# Out:
# hello, world

# %% [markdown]
# # Comment

# %%
# use print to display message
print('hello, world')
# Out:
# hello, world

# %%
''' use print to display message
message between single or double quote '''
print('hello, world')
# Out:
# hello, world

# %% [markdown]
# # Variables and Types
# * In programming, a variable is a container (storage area) to hold data
# * Specific, case-sensitive name
# * Call up value through variable name

# %%
x = 1
y = 1.99
check = True
name = 'Ahmed'

print(name)

x , y , name = 1, 1.99, 'Ahmed'
print(name)

name1 = name2 = 'Ahmed'
print(name2)
# Out:
# Ahmed
# Ahmed
# Ahmed

# %% [markdown]
# ### Calculate BMI
# ![u2.png](data:image/png;base64,...)

# %%
height = 1.8
weight = 70

bmi = weight / (height * height)

print('bmi = ',bmi)
# Out:
# bmi =  21.604938271604937

# %% [markdown]
# # Python Types Conversion
# ###In programming, type conversion is the process of converting data of one type to another.
# For example: converting int data to str.
# There are two types of type conversion in Python.
#
# * Implicit Conversion - automatic type conversion
# * Explicit Conversion - manual type conversion

# %%
# Example 1: Converting integer to float
integer_number = 123
float_number = 1.23

new_number = integer_number + float_number

# display new value and resulting data type
print("Value:",new_number)
print("Data Type:",type(new_number))
# Out:
# Value: 124.23
# Data Type: <class 'float'>

# %%
num1 = int("22")
num2 = int("30")
sum = num1 + num2
print(sum)  # Now prints 52

print("##################################")

num1 = 40
num2 = int("10")
sum = num1 + num2
print(sum)
# Out:
# 52
# ##################################
# 50

# %%
# Example 2: Addition of string and integer Using Explicit Conversion
# We use the built-in functions like int(), float(), str(),

num_string = '12'
num_integer = 23

print("Data type of num_string before Type Casting:",type(num_string))

# explicit type conversion
num_string = int(num_string)

print("Data type of num_string after Type Casting:",type(num_string))

num_sum = num_integer + num_string

print("Sum:",num_sum)
print("Data type of num_sum:",type(num_sum))
# Out:
# Data type of num_string before Type Casting: <class 'str'>
# Data type of num_string after Type Casting: <class 'int'>
# Sum: 35
# Data type of num_sum: <class 'int'>

# %% [markdown]
# # Python Basic Input and Output

# %%
# Example 1: Python print() with end Parameter
# print with end whitespace

print('Good Morning!', end= ' ')
print('It is rainy today')
# Out:
# Good Morning! It is rainy today

# %%
# Output formatting
name = 'ali'
age = 20

print('my name is {} and i am {} years old'. format(name,age))
# Out:
# my name is ali and i am 20 years old

# %%
# Example: Python User Input
name = input('Enter your name: ')
age = input('Enter your age: ')

print('my name is {} and i am {} years old'.format(name,age))
# Out:
# Enter your name: ali
# Enter your age: 23
# my name is ali and i am 23 years old

# %% [markdown]
# # Python Operators
# ### Types of Python Operators
# Here's a list of different types of Python operators
#
# * Arithmetic Operators
# * Assignment Operators
# * Comparison Operators
# * Logical Operators
# * Bitwise Operators
# * Special Operators

# %% [markdown]
# ### 1. Python Arithmetic Operators
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, etc.
# ![DeepinScreenshot_select-area_٢٠٢٤٠٧٠٤١٦١٥٥٢.png](data:image/png;base64,...)

# %%
a = 7
b = 2

# addition
print ('Sum: ', a + b)

# subtraction
print ('Subtraction: ', a - b)

# multiplication
print ('Multiplication: ', a * b)

# division
print ('Division: ', a / b)

# floor division
print ('Floor Division: ', a // b)

# modulo
print ('Modulo: ', a % b)

# a to the power b
print ('Power: ', a ** b)
# Out:
# Sum:  9
# Subtraction:  5
# Multiplication:  14
# Division:  3.5
# Floor Division:  3
# Modulo:  1
# Power:  49

# %% [markdown]
# ### Example 2: Assignment Operators

# %%
# assign the sum of a and b to a
a += b      # a = a + b
a *= b      # a = a * b

# a = ?????????????

# %% [markdown]
# ### Example 3: Comparison Operators

# %%
a = 5

b = 2

# equal to operator
print('a == b =', a == b)

# not equal to operator
print('a != b =', a != b)

# greater than operator
print('a > b =', a > b)

# greater than or equal to operator
print('a >= b =', a >= b)
# Out:
# a == b = False
# a != b = True
# a > b = True
# a >= b = True

# %% [markdown]
# # 4. Python Logical Operators
# Logical operators are used to check whether an expression is True or False. They are used in decision-making
# ![u44.png](data:image/png;base64,...)

# %%
grade = 80
gpa = 'B'

print(grade>70 and gpa=='B')

print(grade>70 and gpa=='A')

print(grade>70 or gpa=='A')

print(grade>70 and (gpa=='A' or gpa=='B'))

print(not(grade>70 and gpa=='A'))
# Out:
# True
# False
# True
# True
# True

# %% [markdown]
# ### Example 5: Membership operators in Python

# %%
message = 'Hello world'
dict1 = {1:'a', 2:'b'}

# check if 'H' is present in message string
print('H' in message)  # prints True

# check if 'hello' is present in message string
print('hello' not in message)  # prints True

# check if '1' key is present in dict1
print(1 in dict1)  # prints True

# check if 'a' key is present in dict1
print('a' in dict1)  # prints False
# Out:
# True
# True
# True
# False

# %% [markdown]
# # Python Flow Control
# * if...else Statement
# * for Loop
# * while Loop
# * break and continue
# * pass Statement

# %% [markdown]
# ### Python if...else Statement
# An if statement can have an optional else clause. The else statement executes if the condition in the if statement evaluates to False.
#
# ![python-if-else.png](data:image/png;base64,...)

# %%
number = 10

# check if number is greater than 0
if number > 0:
    print('Number is positive')

print('This statement always executes')
# Out:
# Number is positive
# This statement always executes

# %%
number = -2

if number > 0:
    print('Positive number')

else:
    print('Negative number')

print('This statement always executes')
# Out:
# Negative number
# This statement always executes

# %%
number = 0

if number > 0:
    print('Positive number')

elif number <0:
    print('Negative number')

else:
    print('Zero')

print('This statement is always executed')
# Out:
# Zero
# This statement is always executed

# %% [markdown]
# ### Python for Loop
# In Python, a for loop is used to iterate over sequences such as lists, strings, tuples, etc.

# %%
language = 'Python'

# iterate over each character in language
for x in language:
    print(x)


languages = ['Swift', 'Python', 'Go']
# access elements of the list one by one
for i in languages:
    print(i)
# Out:
# P
# y
# t
# h
# o
# n
# Swift
# Python
# Go

# %%
# iterate from i = 0 to i = 3
for i in range(0,4):            ## start , end , num_step
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ### Python while Loop
# In Python, we use the while loop to repeat a block of code until a certain condition is met.

# %%
number = 1

while number <= 3:
    print("hello")
    number = number + 1
# Out:
# hello
# hello
# hello

# %% [markdown]
# ### Calculate the sum of numbers until user enters 0

# %%
number = int(input('Enter a number: '))

total = 0

# iterate until the user enters 0
while number != 0:
    total += number
    number = int(input('Enter a number: '))

print('The sum is', total)
# Out:
# Enter a number: 7
# Enter a number: 8
# Enter a number: 0
# The sum is 15

# %% [markdown]
# # Python break and continue
# In programming, the break and continue statements are used to alter the flow of loops:
#
# * **break** exits the loop entirely
#
# * **continue** skips the current iteration and proceeds to the next one

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %% [markdown]
# # Python Data types
# * List
# * Tuple
# * Sets
# * Dictionary
# * String

# %% [markdown]
# ### Python List
# In Python, lists allow us to store a sequence of items in a single variable.
#
# ### List Characteristics
#
# * Ordered - They maintain the order of elements.
# * Mutable - Items can be changed after creation.
# * Allow duplicates - They can contain duplicate values

# %%
# a list of three elements
ages = [19, 26, 29]
print(ages)

# a list of three elements
ages = [19, 'twenty-sex', 29]
print(ages)
# Out:
# [19, 26, 29]
# [19, 'twenty-sex', 29]

# %%
# Access Elements Using Index
# We use index numbers to access list elements. For example,

languages = ['Python', 'Swift', 'C++']
# access the first element
print(languages[0])
# access the third element
print(languages[2])


#Add Elements to a Python List
languages.append('java')
print(languages)

# Change List Items
languages[2]='Go'
print(languages)

#Remove an Item From a List
languages.remove('java')
print(languages)

#Python List Length
print(len(languages))


#Iterating Through a List
for x in languages:
    print(x)

#slicing
print(languages[0:2])
print(languages[1:])
print(languages[:2])
print(languages[:])
print(languages[-1])
# Out:
# Python
# C++
# ['Python', 'Swift', 'C++', 'java']
# ['Python', 'Swift', 'Go', 'java']
# ['Python', 'Swift', 'Go']
# 3
# Python
# Swift
# Go
# ['Python', 'Swift']
# ['Swift', 'Go']
# ['Python', 'Swift']
# ['Python', 'Swift', 'Go']
# Go
# 1

# %% [markdown]
# # Python List Methods
# * append()	Adds an item to the end of the list
# * extend()	Adds items of lists and other iterables to the end of the list
# * insert()	Inserts an item at the specified index
# * remove()	Removes item present at the given index
# * pop()	Returns and removes item present at the given index
# * clear()	Removes all items from the list
# * index()	Returns the index of the first matched item
# * count()	Returns the count of the specified item in the list
# * sort()	Sorts the list in ascending/descending order
# * reverse()	Reverses the item of the list
# * copy()	Returns the shallow copy of the list

# %% [markdown]
# ---------------------------------------------------------

# %% [markdown]
# ### Python Tuple
# A tuple is a collection similar to a Python list. The primary difference is that we cannot modify a tuple once it is created.
#
# ###Tuple Characteristics
# * Ordered - They maintain the order of elements.
# * Immutable - They cannot be changed after creation.
# * Allow duplicates - They can contain duplicate values.

# %%
# Access Elements Using Index
# We use index numbers to access list elements. For example,

languages = ['Python', 'Swift', 'C++']
# access the first element
print(languages[0])
# access the third element
print(languages[2])


#Add Elements to a Python Tuple
languages.append('Java')   ## ??????????
print(languages)

# Change Tuple Items
languages[2]='Go'         ## ??????????
print(languages)
# Out:
# Python
# C++
# ['Python', 'Swift', 'C++', 'Java']
# ['Python', 'Swift', 'Go', 'Java']

# %% [markdown]
# ### Python Sets
# A set is a collection of unique data, meaning that elements within a set cannot be duplicated.
#
# For instance, if we need to store information about student IDs, a set is suitable since student IDs cannot have duplicates.

# %%
# create a set
student_id = {112, 114, 116, 118, 115,110,112}
print('Student ID:', student_id)

#Add Items to a Set in Python
student_id.add(109)
print('Student ID:', student_id)

#Remove Items from a Set in Python
student_id.remove(112)
print('Student ID:', student_id)
# Out:
# Student ID: {112, 114, 115, 116, 118, 110}
# Student ID: {112, 114, 115, 116, 118, 109, 110}
# Student ID: {114, 115, 116, 118, 109, 110}

# %% [markdown]
# Add and Update Set Items in Python
# Sets are mutable. However, since they are unordered, indexing has no meaning.
#
# We **cannot access or change an element of a set using indexing** or slicing. The set data type does not support it.

# %%
companies = {'microsoft', 'facebook'}
tech_companies = ['apple', 'google', 'apple']

# using update() method
companies.update(tech_companies)

print(companies)
# Out:
# {'apple', 'facebook', 'google', 'microsoft'}

# %% [markdown]
# ### built function with set
# * all()	Returns True if all elements of the set are true (or if the set is empty).
# * any()	Returns True if any element of the set is true. If the set is empty, returns False.
# * enumerate()	Returns an enumerate object. It contains the index and value for all the items of the set as a pair.
# * len()	Returns the length (the number of items) in the set.
# * max()	Returns the largest item in the set.
# * min()	Returns the smallest item in the set.
# * sorted()	Returns a new sorted list from elements in the set(does not sort the set itself).
# * sum()	Returns the sum of all elements in the set.

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# ### Python Dictionary
# A Python dictionary is a collection of items, similar to lists and tuples. However, unlike lists and tuples, each item in a dictionary is a key-value pair (consisting of a key and a value).

# %%
# creating a dictionary
country_capitals = {
  "Germany": "Berlin",
  "Egypt": "Cairo",
  "England": "London"
}

# printing the dictionary
print(country_capitals)

# access the value of keys
print(country_capitals["Germany"])
print(country_capitals["England"])

# add an item with "Italy" as key and "Rome" as its value
country_capitals["Italy"] = "Rome"
print(country_capitals)

# delete item having "Germany" key
del country_capitals["Germany"]

#iterate
for key, value in country_capitals.items():
    print(key, value)
# Out:
# {'Germany': 'Berlin', 'Egypt': 'Cairo', 'England': 'London'}
# Berlin
# London
# {'Germany': 'Berlin', 'Egypt': 'Cairo', 'England': 'London', 'Italy': 'Rome'}
# Egypt Cairo
# England London
# Italy Rome
